# %%
# Load CSV File
import pandas as pd
# filename = pd.read_csv("data/bestsellers.csv")

filename = "data/bestsellers.csv"
data = pd.read_csv(filename)
data
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
file = "data/car_financing.xlsx"
info = pd.read_excel(file)
info
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0        1          34689.96     687.23         202.93          484.30
# 1        2          34205.66     687.23         200.10          487.13
# 2        3          33718.53     687.23         197.25          489.98
# 3        4          33228.55     687.23         194.38          492.85
# 4        5          32735.70     687.23         191.50          495.73
# ..     ...               ...        ...            ...             ...
# 403     56           3951.11     796.01           9.54          786.47
# 404     57           3164.64     796.01           7.64          788.37
# 405     58           2376.27     796.01           5.74          790.27
# 406     59           1586.00     796.01           3.83          792.18
# 407     60            793.82     796.01           1.91          794.10
#
#      New Balance  term  interest_rate       car_type
# 0       34205.66    60         0.0702  Toyota Sienna
# ...

# %%
info.head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1          34689.96     687.23         202.93          484.30
# 1      2          34205.66     687.23         200.10          487.13
# 2      3          33718.53     687.23         197.25          489.98
# 3      4          33228.55     687.23         194.38          492.85
# 4      5          32735.70     687.23         191.50          495.73
#
#    New Balance  term  interest_rate       car_type
# 0     34205.66    60         0.0702  Toyota Sienna
# 1     33718.53    60         0.0702  Toyota Sienna
# 2     33228.55    60         0.0702  Toyota Sienna
# 3     32735.70    60         0.0702  Toyota Sienna
# 4     32239.97    60         0.0702  Toyota Sienna

# %%
info.tail()
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 403     56           3951.11     796.01           9.54          786.47
# 404     57           3164.64     796.01           7.64          788.37
# 405     58           2376.27     796.01           5.74          790.27
# 406     59           1586.00     796.01           3.83          792.18
# 407     60            793.82     796.01           1.91          794.10
#
#      New Balance  term  interest_rate   car_type
# 403      3164.64    60          0.029  VW Golf R
# 404      2376.27    60          0.029  VW Golf R
# 405      1586.00    60          0.029  VW Golf R
# 406       793.82    60          0.029  VW Golf R
# 407        -0.28    60          0.029  VW Golf R

# %%
info.shape
# Out:
# (408, 9)

# %%
info.dtypes
# Out:
# Month                 int64
# Starting Balance    float64
# Repayment           float64
# Interest Paid       float64
# Principal Paid      float64
# New Balance         float64
# term                  int64
# interest_rate       float64
# car_type             object
# dtype: object

# %%
info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month             408 non-null    int64
#  1   Starting Balance  408 non-null    float64
#  2   Repayment         408 non-null    float64
#  3   Interest Paid     407 non-null    float64
#  4   Principal Paid    408 non-null    float64
#  5   New Balance       408 non-null    float64
#  6   term              408 non-null    int64
#  7   interest_rate     408 non-null    float64
#  8   car_type          408 non-null    object
# dtypes: float64(6), int64(2), object(1)
# memory usage: 28.8+ KB

# %%
# Slicing 
## [[ doubleSquare bracket ]], do select one column
info[['Starting Balance']].head()
# Out:
#    Starting Balance
# 0          34689.96
# 1          34205.66
# 2          33718.53
# 3          33228.55
# 4          32735.70

# %%
info[['car_type', 'Principal Paid']].head()
# Out:
#         car_type  Principal Paid
# 0  Toyota Sienna          484.30
# 1  Toyota Sienna          487.13
# 2  Toyota Sienna          489.98
# 3  Toyota Sienna          492.85
# 4  Toyota Sienna          495.73

# %%
info['car_type']
# Out:
# 0      Toyota Sienna
# 1      Toyota Sienna
# 2      Toyota Sienna
# 3      Toyota Sienna
# 4      Toyota Sienna
#            ...
# 403        VW Golf R
# 404        VW Golf R
# 405        VW Golf R
# 406        VW Golf R
# 407        VW Golf R
# Name: car_type, Length: 408, dtype: object

# %%
info['car_type'][0:10]
# Out:
# 0    Toyota Sienna
# 1    Toyota Sienna
# 2    Toyota Sienna
# 3    Toyota Sienna
# 4    Toyota Sienna
# 5    Toyota Sienna
# 6    Toyota Sienna
# 7    Toyota Sienna
# 8    Toyota Sienna
# 9    Toyota Sienna
# Name: car_type, dtype: object

# %%
# Selecting Columns using loc
# pandas dataframe
info.loc[:, ['car_type']].head()
# Out:
#         car_type
# 0  Toyota Sienna
# 1  Toyota Sienna
# 2  Toyota Sienna
# 3  Toyota Sienna
# 4  Toyota Sienna

# %%
# pandas series
info.loc[:, 'car_type'].head()
# Out:
# 0    Toyota Sienna
# 1    Toyota Sienna
# 2    Toyota Sienna
# 3    Toyota Sienna
# 4    Toyota Sienna
# Name: car_type, dtype: object

# %%
info['car_type'].value_counts()
# Out:
# VW Golf R         144
# Toyota Sienna     120
# Toyota Carolla    111
# Toyota Corolla     33
# Name: car_type, dtype: int64

# %%
# A filter produces a pandas series of True and False values
car_filter = info['car_type'] == 'Toyota Sienna'
car_filter
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 403    False
# 404    False
# 405    False
# 406    False
# 407    False
# Name: car_type, Length: 408, dtype: bool

# %%
info[car_filter].head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1          34689.96     687.23         202.93          484.30
# 1      2          34205.66     687.23         200.10          487.13
# 2      3          33718.53     687.23         197.25          489.98
# 3      4          33228.55     687.23         194.38          492.85
# 4      5          32735.70     687.23         191.50          495.73
#
#    New Balance  term  interest_rate       car_type
# 0     34205.66    60         0.0702  Toyota Sienna
# 1     33718.53    60         0.0702  Toyota Sienna
# 2     33228.55    60         0.0702  Toyota Sienna
# 3     32735.70    60         0.0702  Toyota Sienna
# 4     32239.97    60         0.0702  Toyota Sienna

# %%
# Filter dataframe to get a DataFrame of only 'Toyota Siena'
info.loc[car_filter, :]
info['car_type'].value_counts()
# Out:
# VW Golf R         144
# Toyota Sienna     120
# Toyota Carolla    111
# Toyota Corolla     33
# Name: car_type, dtype: int64

# %%
filteredInfo = info.loc[car_filter, :]
filteredInfo['car_type'].value_counts()
# Out:
# Toyota Sienna    120
# Name: car_type, dtype: int64

# %%
filteredInfo['interest_rate'].value_counts()
# Out:
# 0.0702    60
# 0.0359    60
# Name: interest_rate, dtype: int64

# %%
filteredInfo['interest_rate'] == 0.0702
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 115    False
# 116    False
# 117    False
# 118    False
# 119    False
# Name: interest_rate, Length: 120, dtype: bool

# %%
interestFilter = filteredInfo['interest_rate']  == 0.0702
info = filteredInfo.loc[interestFilter, :]
info['interest_rate'].value_counts(dropna=False)
# Out:
# 0.0702    60
# Name: interest_rate, dtype: int64

# %%
info.loc[car_filter & interestFilter, :].head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1          34689.96     687.23         202.93          484.30
# 1      2          34205.66     687.23         200.10          487.13
# 2      3          33718.53     687.23         197.25          489.98
# 3      4          33228.55     687.23         194.38          492.85
# 4      5          32735.70     687.23         191.50          495.73
#
#    New Balance  term  interest_rate       car_type
# 0     34205.66    60         0.0702  Toyota Sienna
# 1     33718.53    60         0.0702  Toyota Sienna
# 2     33228.55    60         0.0702  Toyota Sienna
# 3     32735.70    60         0.0702  Toyota Sienna
# 4     32239.97    60         0.0702  Toyota Sienna
