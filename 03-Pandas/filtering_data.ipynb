# %%
import pandas as pd
tinanic = pd.read_csv("data/titanic.csv")

# %%
tinanic.sex
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
#          ...
# 1304    female
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: sex, Length: 1309, dtype: object

# %%
tinanic.sex == 'female'
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 1304     True
# 1305     True
# 1306    False
# 1307    False
# 1308    False
# Name: sex, Length: 1309, dtype: bool

# %%
tinanic[tinanic.sex == 'female']
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
houses = pd.read_csv("data/kc_house_data.csv")
houses["sqft_living"] <= 500
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Name: sqft_living, Length: 21613, dtype: bool

# %%
houses[houses["sqft_living"] <= 500]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 465    8658300340  20140523T000000   80000.0         1       0.75
# 860    1723049033  20140620T000000  245000.0         1       0.75
# 1168   3523029041  20141009T000000  290000.0         2       0.75
# 4203   1437500015  20140709T000000  150000.0         3       0.75
# 4651    859000110  20141002T000000  125000.0         1       1.00
# 4868   6896300380  20141002T000000  228000.0         0       1.00
# 8133   7849202585  20140904T000000  170000.0         1       1.00
# 8623   6303400395  20150130T000000  325000.0         1       0.75
# 11500  4322200105  20150331T000000  229050.0         1       1.00
# 12075  8655900162  20150219T000000  156000.0         1       0.75
# 14466  7549801385  20140612T000000  280000.0         1       0.75
# 15248  1320069249  20141020T000000  192500.0         1       1.00
# 15381  2856101479  20140701T000000  276000.0         1       0.75
# ...

# %% [markdown]
# ## between method

# %%
# get house between 5 and 7 bedroom
houses['bedrooms'].between(5, 7).value_counts()
# Out:
# False    19702
# True      1911
# Name: bedrooms, dtype: int64

# %%
houses[houses["bedrooms"].between(5, 7)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 14     1175000570  20150312T000000   530000.0         5       2.00
# 22     7137970340  20140703T000000   285000.0         5       2.50
# 42     7203220400  20140707T000000   861990.0         5       2.75
# 51     7231300125  20150217T000000   345000.0         5       2.50
# 54     4217401195  20150303T000000   920000.0         5       2.25
# ...           ...              ...        ...       ...        ...
# 21564  7168100015  20141009T000000   579950.0         5       2.75
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
# 21593  8672200110  20150317T000000  1088000.0         5       3.75
# 21596  7502800100  20140813T000000   679950.0         5       2.75
# 21600   249000205  20141015T000000  1537000.0         5       3.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 14            1810      4850     1.5           0     0  ...      7
# ...

# %%
houses[houses["bedrooms"].between(5, 7)].bedrooms.value_counts()
# Out:
# 5    1601
# 6     272
# 7      38
# Name: bedrooms, dtype: int64

# %% [markdown]
# ## isin() method

# %%
bedrooms = [1,2,3]
houses["bedrooms"].isin(bedrooms)
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 21608     True
# 21609    False
# 21610     True
# 21611     True
# 21612     True
# Name: bedrooms, Length: 21613, dtype: bool

# %%
houses[houses['bedrooms'].isin(bedrooms)]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# 6      1321400060  20140627T000000  257500.0         3       2.25
# ...           ...              ...       ...       ...        ...
# 21607  2997800021  20150219T000000  475000.0         3       2.50
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# ## Combine multiple condition

# %%
# find condition with the houses at the waterfront, 3 bedroom, and affordable
waterfront = houses["waterfront"] == 1
waterfront
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Name: waterfront, Length: 21613, dtype: bool

# %%
threebedrooms = houses["bedrooms"] == 3
threebedrooms
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 21608     True
# 21609    False
# 21610    False
# 21611     True
# 21612    False
# Name: bedrooms, Length: 21613, dtype: bool

# %%
affordable = houses['price'] < 600000
affordable
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 21608     True
# 21609     True
# 21610     True
# 21611     True
# 21612     True
# Name: price, Length: 21613, dtype: bool

# %%
houses[waterfront & threebedrooms & affordable]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 1484   8888000055  20141230T000000  530000.0         3       0.75
# 8277    221029019  20150428T000000  400000.0         3       2.50
# 8450    121039042  20150313T000000  425000.0         3       2.75
# 11556  2013802030  20140911T000000  357000.0         3       2.00
# 17474  6329000185  20150329T000000  540000.0         3       2.50
# 18848  7631800110  20140918T000000  380000.0         3       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1484           920     20412     1.0           1     2  ...      6
# 8277          2090     32718     2.0           1     4  ...      7
# 8450          3610    107386     1.5           1     3  ...      8
# 11556         2460     53882     1.0           1     4  ...      7
# 17474         2600     23361     1.5           1     4  ...      8
# 18848         1980     17342     2.0           1     4  ...     10
#
# ...

# %%
# get a dream home
high_quality = houses["grade"] >= 11
good_view = houses["view"] == 4
smaller = houses["sqft_living"] <= 3000
houses[high_quality & good_view & smaller]
# Out:
#              id             date      price  bedrooms  bathrooms  sqft_living  \
# 4013  724069059  20140509T000000  2400000.0         3       2.25         3000
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 4013     11665     1.5           1     4  ...     11        3000
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 4013              0      2001             0    98075  47.5884 -122.086
#
#       sqft_living15  sqft_lot15
# 4013           3000       15959
#
# [1 rows x 21 columns]

# %%
# find newer condition home using OR

houses[houses["yr_built"] >= 2014]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 42     7203220400  20140707T000000  861990.0         5       2.75
# 63     9528102996  20141207T000000  549000.0         3       1.75
# 133    8929000270  20140512T000000  453246.0         3       2.50
# 139    2767603505  20140507T000000  519950.0         3       2.25
# 211    1025049114  20140717T000000  625504.0         3       2.25
# ...           ...              ...       ...       ...        ...
# 21598  8956200760  20141013T000000  541800.0         4       2.50
# 21602   844000965  20140626T000000  224000.0         3       1.75
# 21604  9834201367  20150126T000000  429000.0         3       2.00
# 21605  3448900210  20141014T000000  610685.0         4       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 42            3595      5639     2.0           0     0  ...      9
# ...

# %%
houses[houses["yr_renovated"] >= 2014]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 379    7132300695  20150421T000000   435000.0         3       1.50
# 435    2268400350  20140916T000000   749000.0         4       2.50
# 891    1962200435  20141110T000000  1010000.0         4       1.00
# 1379   1453600202  20140520T000000   520000.0         4       3.50
# 1449   8651430560  20140522T000000   180000.0         3       1.00
# ...           ...              ...        ...       ...        ...
# 19174  2420069220  20141203T000000   209000.0         3       1.00
# 19276  2397100705  20140714T000000  1518630.0         4       4.25
# 19444   582000644  20150501T000000   872500.0         4       2.00
# 19593   421059018  20141104T000000   257000.0         3       1.75
# 20447  3319500628  20150212T000000   356999.0         3       1.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 379           1300      3348     1.5           0     0  ...      7
# ...

# %%
newer_condition = houses[(houses["yr_built"] >= 2014) | (houses["yr_renovated"] >= 2014)]

# %%
newer_condition.sort_values("yr_renovated")
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 42     7203220400  20140707T000000   861990.0         5       2.75
# 20563   715010110  20140804T000000  1240420.0         5       3.25
# 20567  6926700654  20140921T000000   700000.0         2       2.00
# 20569  8895800110  20140805T000000  1299890.0         5       4.00
# 20576  3277801592  20140925T000000   479950.0         3       2.00
# ...           ...              ...        ...       ...        ...
# 2295   8712100320  20140728T000000   585000.0         5       2.75
# 3156   6821100195  20150331T000000   830000.0         4       3.00
# 11599  7284900030  20140522T000000   850000.0         4       3.25
# 16683  5113000420  20150320T000000   420000.0         4       2.75
# 11633   461004730  20150406T000000   717000.0         3       1.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 42            3595      5639     2.0           0     0  ...      9
# ...

# %% [markdown]
# ## Apply and filter base on Multiple condition

# %%
netflix = pd.read_csv("data/netflix_titles.csv", sep="|")
netflix["director"].value_counts()
# Out:
# Rajiv Chilaka                     19
# Raúl Campos, Jan Suter            18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
#                                   ..
# Raymie Muzquiz, Stu Livingston     1
# Joe Menendez                       1
# Eric Bross                         1
# Will Eisenberg                     1
# Mozez Singh                        1
# Name: director, Length: 4528, dtype: int64

# %%
netflix[(netflix["director"] == "David Fincher") | (netflix["director"] == "Martin Scorsese")]
# Out:
#       Unnamed: 0 show_id   type  \
# 600          600    s601  Movie
# 1358        1358   s1359  Movie
# 1595        1595   s1596  Movie
# 2632        2632   s2633  Movie
# 2860        2860   s2861  Movie
# 3227        3227   s3228  Movie
# 3759        3759   s3760  Movie
# 6111        6111   s6112  Movie
# 6826        6826   s6827  Movie
# 6880        6880   s6881  Movie
# 7431        7431   s7432  Movie
# 7701        7701   s7702  Movie
# 7820        7820   s7821  Movie
# 8272        8272   s8273  Movie
# 8320        8320   s8321  Movie
# 8511        8511   s8512  Movie
# 8735        8735   s8736  Movie
# 8802        8802   s8803  Movie
#
#                                                   title         director  \
# 600                                            The Game    David Fincher
# 1358                                     Shutter Island  Martin Scorsese
# 1595                                               MANK    David Fincher
# ...

# %%
fincher = netflix["director"] == "David Fincher"
scorsese = netflix["director"] == "Martin Scorsese"
recent = netflix["release_year"] > 2015
netflix[(fincher | scorsese) & recent]
# Out:
#       Unnamed: 0 show_id   type  \
# 1595        1595   s1596  Movie
# 3227        3227   s3228  Movie
# 3759        3759   s3760  Movie
#
#                                                   title         director  \
# 1595                                               MANK    David Fincher
# 3227                                       The Irishman  Martin Scorsese
# 3759  Rolling Thunder Revue: A Bob Dylan Story by Ma...  Martin Scorsese
#
#                                                    cast        country  \
# 1595  Gary Oldman, Amanda Seyfried, Charles Dance, L...  United States
# 3227  Robert De Niro, Al Pacino, Joe Pesci, Harvey K...  United States
# 3759  Bob Dylan, Allen Ginsberg, Joan Baez, Patti Sm...  United States
#
#              date_added  release_year rating duration  \
# 1595   December 4, 2020          2020      R  133 min
# 3227  November 27, 2019          2019      R  209 min
# 3759      June 12, 2019          2019  TV-MA  142 min
#
# ...

# %% [markdown]
# ## To Negate the element

# %%
df = tinanic.head()
women = df.sex == "female"
women
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: sex, dtype: bool

# %%
~women
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: sex, dtype: bool

# %%
df[~women]
# Out:
#    pclass  survived                                  name   sex     age  \
# 1       1         1        Allison, Master. Hudson Trevor  male  0.9167
# 3       1         0  Allison, Mr. Hudson Joshua Creighton  male      30
#
#    sibsp  parch  ticket    fare    cabin embarked boat body  \
# 1      1      2  113781  151.55  C22 C26        S   11    ?
# 3      1      2  113781  151.55  C22 C26        S    ?  135
#
#                          home.dest
# 1  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON

# %%
df[women]
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#   age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0  29      0      0   24160  211.3375       B5        S    2    ?
# 2   2      1      2  113781    151.55  C22 C26        S    ?    ?
# 4  25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 2  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# ## The tilt method is a good way to get a flip of the opposite of what we select.

# %%
newly_built = houses["yr_built"] >= 2014
newly_renovate = houses["yr_renovated"] >= 2014
modern_homes = newly_built | newly_renovate
houses[modern_homes]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 42     7203220400  20140707T000000  861990.0         5       2.75
# 63     9528102996  20141207T000000  549000.0         3       1.75
# 133    8929000270  20140512T000000  453246.0         3       2.50
# 139    2767603505  20140507T000000  519950.0         3       2.25
# 211    1025049114  20140717T000000  625504.0         3       2.25
# ...           ...              ...       ...       ...        ...
# 21598  8956200760  20141013T000000  541800.0         4       2.50
# 21602   844000965  20140626T000000  224000.0         3       1.75
# 21604  9834201367  20150126T000000  429000.0         3       2.00
# 21605  3448900210  20141014T000000  610685.0         4       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 42            3595      5639     2.0           0     0  ...      9
# ...

# %%
# older home
houses[~modern_homes]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21607  2997800021  20150219T000000  475000.0         3       2.50
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
# people is not survived
tinanic[tinanic.survived == 0]
# Out:
#       pclass  survived                                             name  \
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 7          1         0                           Andrews, Mr. Thomas Jr
# 9          1         0                          Artagaveytia, Mr. Ramon
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex   age  sibsp  parch    ticket     fare    cabin embarked boat  \
# ...

# %%
# people is survide
tinanic[~(tinanic.survived == 0)]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1261       3         1                           Turkula, Mrs. (Hedwig)
# 1277       3         1                             Vartanian, Mr. David
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked   boat  \
# ...

# %%
women = tinanic["sex"] == "female"
tinanic[women]["survived"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='survived'>

# %%
# male
tinanic[~women]["survived"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='survived'>

# %%
houses[houses["price"] > 3000000].zipcode.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
#top 10 sales for all the housed base on zipcode
houses.zipcode.value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# # Filter exercise

# %%
import pandas as pd 
books = pd.read_csv("data/bestsellers.csv")
books.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %% [markdown]
# ### find the books written by Pete Souza

# %%
books[books["Author"] == "Pete Souza"]
# Out:
#                             Name      Author  User Rating  Reviews  Price  \
# 244  Obama: An Intimate Portrait  Pete Souza          4.9     3192     22
#
#      Year        Genre
# 244  2017  Non Fiction

# %% [markdown]
# ### find the books that are under 10 dollars

# %%
books[books["Price"] < 10]
# Out:
#                                                   Name           Author  \
# 0                        10-Day Green Smoothie Cleanse         JJ Smith
# 3                               1984 (Signet Classics)    George Orwell
# 8        A Higher Loyalty: Truth, Lies, and Leadership      James Comey
# 9                            A Man Called Ove: A Novel  Fredrik Backman
# 10                           A Man Called Ove: A Novel  Fredrik Backman
# ..                                                 ...              ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)      Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...      Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %% [markdown]
# ### find the books that have a price between 50 and 60 dollars

# %%
books[books["Price"].between(50, 60)]
# Out:
#                                                   Name              Author  \
# 151                           Hamilton: The Revolution  Lin-Manuel Miranda
# 159         Harry Potter Paperback Box Set (Books 1-7)       J. K. Rowling
# 346  The Book of Basketball: The NBA According to T...        Bill Simmons
#
#      User Rating  Reviews  Price  Year        Genre
# 151          4.9     5867     54  2016  Non Fiction
# 159          4.8    13471     52  2016      Fiction
# 346          4.7      858     53  2009  Non Fiction

# %% [markdown]
# ### find all the books written by Kristin Hannah, Andy Weir, or Delia Owens

# %%
authors = ["Kristin Hannah", "Andy Weir", "Delia Owens"]
books[books["Author"].isin(authors)]
# Out:
#                          Name          Author  User Rating  Reviews  Price  \
# 433               The Martian       Andy Weir          4.7    39459      9
# 437  The Nightingale: A Novel  Kristin Hannah          4.8    49288     11
# 438  The Nightingale: A Novel  Kristin Hannah          4.8    49288     11
# 534   Where the Crawdads Sing     Delia Owens          4.8    87841     15
#
#      Year    Genre
# 433  2015  Fiction
# 437  2015  Fiction
# 438  2016  Fiction
# 534  2019  Fiction

# %% [markdown]
# ### Find the Non Fiction books that are rated 4.9

# %%
highRatedNonfiction = (books["Genre"] == "Non Fiction") & (books["User Rating"] == 4.9)
books[highRatedNonfiction]
# Out:
#                                                   Name              Author  \
# 151                           Hamilton: The Revolution  Lin-Manuel Miranda
# 174                       Humans of New York : Stories     Brandon Stanton
# 187  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 188  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 189  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 190  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 191  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 192  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 244                        Obama: An Intimate Portrait          Pete Souza
# 431                                 The Magnolia Story         Chip Gaines
# 521                             Unfreedom of the Press       Mark R. Levin
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %% [markdown]
# ### Find the fiction book with the lowest User Rating

# %%
books[books["Genre"] == "Fiction"].sort_values("User Rating")
# Out:
#                                                   Name           Author  \
# 353                                 The Casual Vacancy     J.K. Rowling
# 132                         Go Set a Watchman: A Novel       Harper Lee
# 107  Fifty Shades of Grey: Book One of the Fifty Sh...        E L James
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...        E L James
# 392  The Goldfinch: A Novel (Pulitzer Prize for Fic...      Donna Tartt
# ..                                                 ...              ...
# 41            Brown Bear, Brown Bear, What Do You See?  Bill Martin Jr.
# 40            Brown Bear, Brown Bear, What Do You See?  Bill Martin Jr.
# 476                        The Very Hungry Caterpillar       Eric Carle
# 478                        The Very Hungry Caterpillar       Eric Carle
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)      Jeff Kinney
#
#      User Rating  Reviews  Price  Year    Genre
# 353          3.3     9372     12  2012  Fiction
# ...

# %% [markdown]
# ### Find 2012's top 5 Fiction books with the most Reviews

# %%
df = books[(books["Year"] == 2012) & (books["Genre"] == "Fiction")]
df.sort_values("Reviews", ascending=False).head()
# Out:
#                                                   Name           Author  \
# 135                                          Gone Girl    Gillian Flynn
# 365                             The Fault in Our Stars       John Green
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...        E L James
# 409                          The Hunger Games (Book 1)  Suzanne Collins
# 238                      Mockingjay (The Hunger Games)  Suzanne Collins
#
#      User Rating  Reviews  Price  Year    Genre
# 135          4.0    57271     10  2012  Fiction
# 365          4.7    50482     13  2012  Fiction
# 106          3.8    47265     14  2012  Fiction
# 409          4.7    32122      8  2012  Fiction
# 238          4.5    26741      8  2012  Fiction

# %% [markdown]
# ### Create a bar plot showing the 5 authors who have the most books with the rating under 4.5

# %%
low_rated = books[books["User Rating"] < 4.5]
low_rated["Author"].value_counts().head().plot(kind="bar")
# Out:
# <Axes: >
