# %%
import pandas as pd
movielist = pd.read_csv("data/netflix_titles.csv", sep="|")
movielist.head()
# Out:
#    Unnamed: 0 show_id     type                  title         director  \
# 0           0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2  TV Show          Blood & Water              NaN
# 2           2      s3  TV Show              Ganglands  Julien Leclercq
# 3           3      s4  TV Show  Jailbirds New Orleans              NaN
# 4           4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# ...

# %%
movielist['type']
# Out:
# 0         Movie
# 1       TV Show
# 2       TV Show
# 3       TV Show
# 4       TV Show
#          ...
# 8802      Movie
# 8803    TV Show
# 8804      Movie
# 8805      Movie
# 8806      Movie
# Name: type, Length: 8807, dtype: object

# %%
# to rename the column
movielist = movielist.rename(columns={
    'type' : 'movie type'
})
movielist.head()
# Out:
#    Unnamed: 0 show_id movie type                  title         director  \
# 0           0      s1      Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2    TV Show          Blood & Water              NaN
# 2           2      s3    TV Show              Ganglands  Julien Leclercq
# 3           3      s4    TV Show  Jailbirds New Orleans              NaN
# 4           4      s5    TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# ...

# %%
# to delete column or drop 
movielist = movielist.drop(columns='date_added')
movielist.head()

# or
# del movielist['date_added']
# Out:
#    Unnamed: 0 show_id movie type                  title         director  \
# 0           0      s1      Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1           1      s2    TV Show          Blood & Water              NaN
# 2           2      s3    TV Show              Ganglands  Julien Leclercq
# 3           3      s4    TV Show  Jailbirds New Orleans              NaN
# 4           4      s5    TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#    release_year rating   duration  \
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
# ...

# %%
carlist = pd.read_excel("data/car_financing.xlsx")
carlist.head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1          34689.96     687.23         202.93          484.30
# 1      2          34205.66     687.23         200.10          487.13
# 2      3          33718.53     687.23         197.25          489.98
# 3      4          33228.55     687.23         194.38          492.85
# 4      5          32735.70     687.23         191.50          495.73
#
#    New Balance  term  interest_rate       car_type
# 0     34205.66    60         0.0702  Toyota Sienna
# 1     33718.53    60         0.0702  Toyota Sienna
# 2     33228.55    60         0.0702  Toyota Sienna
# 3     32735.70    60         0.0702  Toyota Sienna
# 4     32239.97    60         0.0702  Toyota Sienna

# %%
interst_rate = carlist['Interest Paid'].sum
interst_rate
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0      202.93
# 1      200.10
# 2      197.25
# 3      194.38
# 4      191.50
#         ...
# 403      9.54
# 404      7.64
# 405      5.74
# 406      3.83
# 407      1.91
# Name: Interest Paid, Length: 408, dtype: float64>

# %%
carlist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month             408 non-null    int64
#  1   Starting Balance  408 non-null    float64
#  2   Repayment         408 non-null    float64
#  3   Interest Paid     407 non-null    float64
#  4   Principal Paid    408 non-null    float64
#  5   New Balance       408 non-null    float64
#  6   term              408 non-null    int64
#  7   interest_rate     408 non-null    float64
#  8   car_type          408 non-null    object
# dtypes: float64(6), int64(2), object(1)
# memory usage: 28.8+ KB

# %%
interest_missing = carlist['Interest Paid'].isna()
carlist.loc[interest_missing, :]
# Out:
#     Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 35     36          15940.06     687.23            NaN          593.99
#
#     New Balance  term  interest_rate       car_type
# 35     15346.07    60         0.0702  Toyota Sienna

# %%
carlist['Interest Paid'].isna().sum()
# Out:
# 1

# %%
carlist.loc[-interest_missing, :]
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0        1          34689.96     687.23         202.93          484.30
# 1        2          34205.66     687.23         200.10          487.13
# 2        3          33718.53     687.23         197.25          489.98
# 3        4          33228.55     687.23         194.38          492.85
# 4        5          32735.70     687.23         191.50          495.73
# ..     ...               ...        ...            ...             ...
# 403     56           3951.11     796.01           9.54          786.47
# 404     57           3164.64     796.01           7.64          788.37
# 405     58           2376.27     796.01           5.74          790.27
# 406     59           1586.00     796.01           3.83          792.18
# 407     60            793.82     796.01           1.91          794.10
#
#      New Balance  term  interest_rate       car_type
# 0       34205.66    60         0.0702  Toyota Sienna
# ...

# %%
# To prevent error or misinterprete of the data before we do a graph
# we can also use dropna() method to remove the rows that contain NaN value, however this is not the best practice
newList = pd.read_excel("data/car_financing.xlsx").dropna()
newList
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0        1          34689.96     687.23         202.93          484.30
# 1        2          34205.66     687.23         200.10          487.13
# 2        3          33718.53     687.23         197.25          489.98
# 3        4          33228.55     687.23         194.38          492.85
# 4        5          32735.70     687.23         191.50          495.73
# ..     ...               ...        ...            ...             ...
# 403     56           3951.11     796.01           9.54          786.47
# 404     57           3164.64     796.01           7.64          788.37
# 405     58           2376.27     796.01           5.74          790.27
# 406     59           1586.00     796.01           3.83          792.18
# 407     60            793.82     796.01           1.91          794.10
#
#      New Balance  term  interest_rate       car_type
# 0       34205.66    60         0.0702  Toyota Sienna
# ...

# %%
car_financing = pd.read_excel("data/car_financing.xlsx")
car_financing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month             408 non-null    int64
#  1   Starting Balance  408 non-null    float64
#  2   Repayment         408 non-null    float64
#  3   Interest Paid     407 non-null    float64
#  4   Principal Paid    408 non-null    float64
#  5   New Balance       408 non-null    float64
#  6   term              408 non-null    int64
#  7   interest_rate     408 non-null    float64
#  8   car_type          408 non-null    object
# dtypes: float64(6), int64(2), object(1)
# memory usage: 28.8+ KB

# %%
car_financing['Interest Paid'].sum()
# Out:
# 23046.53

# %%
interest_missing = car_financing['Interest Paid'].isna()
car_financing.loc[interest_missing, :]
# Out:
#     Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 35     36          15940.06     687.23            NaN          593.99
#
#     New Balance  term  interest_rate       car_type
# 35     15346.07    60         0.0702  Toyota Sienna

# %%
# to fill in data with value zero is not best practice
# newcar_financing = car_financing['Interest Paid'][30:40].fillna(0)

# %%
backfill_info = car_financing['Interest Paid'][30:40].fillna(method='bfill')
backfill_info
# car_financing['Interest Paid'].sum()
# Out:
# 30    110.32
# 31    106.94
# 32    103.55
# 33    100.13
# 34     96.70
# 35     89.77
# 36     89.77
# 37     86.27
# 38     82.76
# 39     79.22
# Name: Interest Paid, dtype: float64

# %%
frontfill_info = car_financing['Interest Paid'][30:40].fillna(method='ffill')
frontfill_info
# car_financing['Interest Paid'].sum()
# Out:
# 30    110.32
# 31    106.94
# 32    103.55
# 33    100.13
# 34     96.70
# 35     96.70
# 36     89.77
# 37     86.27
# 38     82.76
# 39     79.22
# Name: Interest Paid, dtype: float64

# %%
linear_info = car_financing["Interest Paid"].interpolate(method='linear')
linear_info[30: 40]
# car_financing['Interest Paid'].sum()
# Out:
# 30    110.320
# 31    106.940
# 32    103.550
# 33    100.130
# 34     96.700
# 35     93.235
# 36     89.770
# 37     86.270
# 38     82.760
# 39     79.220
# Name: Interest Paid, dtype: float64

# %%
car_financing['Interest Paid'].sum()
# Out:
# 23046.53

# %%
# Fill in with the value
interest_missing = car_financing['Interest Paid'].isna()
car_financing.loc[interest_missing, 'Interest Paid'] = 93.235
car_financing.sum()
# Out:
# Month                                                           11004
# Starting Balance                                            7165651.1
# Repayment                                                   290550.72
# Interest Paid                                               23139.765
# Principal Paid                                              267410.95
# New Balance                                                6898240.15
# term                                                            21600
# interest_rate                                                  16.158
# car_type            Toyota SiennaToyota SiennaToyota SiennaToyota ...
# dtype: object

# %%
car_financing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month             408 non-null    int64
#  1   Starting Balance  408 non-null    float64
#  2   Repayment         408 non-null    float64
#  3   Interest Paid     408 non-null    float64
#  4   Principal Paid    408 non-null    float64
#  5   New Balance       408 non-null    float64
#  6   term              408 non-null    int64
#  7   interest_rate     408 non-null    float64
#  8   car_type          408 non-null    object
# dtypes: float64(6), int64(2), object(1)
# memory usage: 28.8+ KB
