# %%
import numpy as np
import pandas as pd

# %%
labels = ['a', 'b','c']
my_data = [10,20,30]
arr = np.array(my_data)
d = {'a':10, 'b': 20, 'c':30}

# %%
pd.Series(data = my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data = my_data, index= labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_data, labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr, labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int32

# %%
pd.Series(d)
d
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
pd.Series(data=[sum, print, len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %%
ser1 = pd.Series([1,2,3,4],['USA', 'Germany', 'USSR', 'Japan'])
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser2 = pd.Series([1,2,5,4], ['USA', 'Germany', 'Italy', "Japan"] )
ser1 + ser2
# Out:
# Germany    4.0
# Italy      NaN
# Japan      8.0
# USA        2.0
# USSR       NaN
# dtype: float64

# %%
titanic = pd.read_csv('data/titanic.csv')
titanic.head()
# Out:
#    pclass  survived                                             name     sex
# 0       1         1                    Allen, Miss. Elisabeth Walton  female  \
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body
# 0      29      0      0   24160  211.3375       B5        S    2    ?  \
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
titanic.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
titanic.tail(10)
# Out:
#       pclass  survived                                     name     sex   age
# 1299       3         0                      Yasbeck, Mr. Antoni    male    27  \
# 1300       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female    15
# 1301       3         0                     Youseff, Mr. Gerious    male  45.5
# 1302       3         0                        Yousif, Mr. Wazli    male     ?
# 1303       3         0                    Yousseff, Mr. Gerious    male     ?
# 1304       3         0                     Zabour, Miss. Hileni  female  14.5
# 1305       3         0                    Zabour, Miss. Thamine  female     ?
# 1306       3         0                Zakarian, Mr. Mapriededer    male  26.5
# 1307       3         0                      Zakarian, Mr. Ortin    male    27
# 1308       3         0                       Zimmerman, Mr. Leo    male    29
#
#       sibsp  parch  ticket     fare cabin embarked boat body home.dest
# ...

# %%
#survivors = [a.name for a in titanic.values if a is not None and a.survived == 1]
# survivors = titanic.loc[titanic['survived'] == 1]
# survivors = titanic.loc[titanic['survived'] == 1].name
survivors = titanic.loc[titanic['survived'] == 1][["name", "age"]]
survivors
# Out:
#                                                  name     age
# 0                       Allen, Miss. Elisabeth Walton      29
# 1                      Allison, Master. Hudson Trevor  0.9167
# 5                                 Anderson, Mr. Harry      48
# 6                   Andrews, Miss. Kornelia Theodosia      63
# 8       Appleton, Mrs. Edward Dale (Charlotte Lamson)      53
# ...                                               ...     ...
# 1261                           Turkula, Mrs. (Hedwig)      63
# 1277                             Vartanian, Mr. David      22
# 1286  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)      38
# 1290                 Wilkes, Mrs. James (Ellen Needs)      47
# 1300          Yasbeck, Mrs. Antoni (Selini Alexander)      15
#
# [500 rows x 2 columns]

# %%
netflix = pd.read_csv("data/netflix_titles.csv", sep="|")
netflix
# Out:
#       Unnamed: 0 show_id     type                  title         director
# 0              0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson  \
# 1              1      s2  TV Show          Blood & Water              NaN
# 2              2      s3  TV Show              Ganglands  Julien Leclercq
# 3              3      s4  TV Show  Jailbirds New Orleans              NaN
# 4              4      s5  TV Show           Kota Factory              NaN
# ...          ...     ...      ...                    ...              ...
# 8802        8802   s8803    Movie                 Zodiac    David Fincher
# 8803        8803   s8804  TV Show            Zombie Dumb              NaN
# 8804        8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805        8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806        8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country
# ...

# %%
movies = pd.read_csv("data/netflix_titles.csv", sep="|", index_col=3)
movies
# Out:
#                        Unnamed: 0 show_id     type         director
# title
# Dick Johnson Is Dead            0      s1    Movie  Kirsten Johnson  \
# Blood & Water                   1      s2  TV Show              NaN
# Ganglands                       2      s3  TV Show  Julien Leclercq
# Jailbirds New Orleans           3      s4  TV Show              NaN
# Kota Factory                    4      s5  TV Show              NaN
# ...                           ...     ...      ...              ...
# Zodiac                       8802   s8803    Movie    David Fincher
# Zombie Dumb                  8803   s8804  TV Show              NaN
# Zombieland                   8804   s8805    Movie  Ruben Fleischer
# Zoom                         8805   s8806    Movie     Peter Hewitt
# Zubaan                       8806   s8807    Movie      Mozez Singh
#
#                                                                     cast
# title
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8807 entries, Dick Johnson Is Dead to Zubaan
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    8807 non-null   int64
#  1   show_id       8807 non-null   object
#  2   type          8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 894.5+ KB

# %%
netflix = pd.read_csv("data/netflix_titles.csv", sep="|", names=["green", "yellow", "red"], header=0)
netflix
# Out:
#                                                                                                                                                              green
# 0    s1    Movie   Dick Johnson Is Dead  Kirsten Johnson NaN                                                United States September 25, 2021 2020 PG-13     90 min  \
# 1    s2    TV Show Blood & Water         NaN             Ama Qamata, Khosi Ngema, Gail Mabalane, Thabang... South Africa  September 24, 2021 2021 TV-MA  2 Seasons
# 2    s3    TV Show Ganglands             Julien Leclercq Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabih... NaN           September 24, 2021 2021 TV-MA   1 Season
# 3    s4    TV Show Jailbirds New Orleans NaN             NaN                                                NaN           September 24, 2021 2021 TV-MA   1 Season
# 4    s5    TV Show Kota Factory          NaN             Mayur More, Jitendra Kumar, Ranjan Raj, Alam Kh... India         September 24, 2021 2021 TV-MA  2 Seasons
# ...
