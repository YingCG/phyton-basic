# %%
# To convert Pandas DataFrames to NumPy Arrays
# Appproach 1

import pandas as pd
carLoans = pd.DataFrame({"A": [1, 2], "B": [3, 4]}).to_numpy()
carLoans
# Out:
# array([[1, 3],
#        [2, 4]], dtype=int64)

# %%
homeLoans = pd.DataFrame({"type": ["apartment", "land"], "interest_rate": [0.35, 0.18]})
homeLoans.to_numpy()
# Out:
# array([['apartment', 0.35],
#        ['land', 0.18]], dtype=object)

# %%
homeLoans = pd.DataFrame({"type": ["apartment", "land"], "interest_rate": [0.35, 0.18]})
homeLoans.values
# Out:
# array([['apartment', 0.35],
#        ['land', 0.18]], dtype=object)

# %%
# Approach 2
bestsellers = pd.read_csv("data/bestsellers.csv")
bestsellers.values
# Out:
# array([['10-Day Green Smoothie Cleanse', 'JJ Smith', 4.7, ..., 8, 2016,
#         'Non Fiction'],
#        ['11/22/63: A Novel', 'Stephen King', 4.6, ..., 22, 2011,
#         'Fiction'],
#        ['12 Rules for Life: An Antidote to Chaos', 'Jordan B. Peterson',
#         4.7, ..., 15, 2018, 'Non Fiction'],
#        ...,
#        ['You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life',
#         'Jen Sincero', 4.7, ..., 8, 2017, 'Non Fiction'],
#        ['You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life',
#         'Jen Sincero', 4.7, ..., 8, 2018, 'Non Fiction'],
#        ['You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life',
#         'Jen Sincero', 4.7, ..., 8, 2019, 'Non Fiction']], dtype=object)

# %%
bookbestsellers = pd.read_csv("data/bestsellers.csv")
bookbestsellers.to_numpy()
# Out:
# array([['10-Day Green Smoothie Cleanse', 'JJ Smith', 4.7, ..., 8, 2016,
#         'Non Fiction'],
#        ['11/22/63: A Novel', 'Stephen King', 4.6, ..., 22, 2011,
#         'Fiction'],
#        ['12 Rules for Life: An Antidote to Chaos', 'Jordan B. Peterson',
#         4.7, ..., 15, 2018, 'Non Fiction'],
#        ...,
#        ['You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life',
#         'Jen Sincero', 4.7, ..., 8, 2017, 'Non Fiction'],
#        ['You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life',
#         'Jen Sincero', 4.7, ..., 8, 2018, 'Non Fiction'],
#        ['You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life',
#         'Jen Sincero', 4.7, ..., 8, 2019, 'Non Fiction']], dtype=object)

# %%
best_sellers = pd.read_csv("data/bestsellers.csv")
best_sellers.to_dict()
# Out:
# {'Name': {0: '10-Day Green Smoothie Cleanse',
#   1: '11/22/63: A Novel',
#   2: '12 Rules for Life: An Antidote to Chaos',
#   3: '1984 (Signet Classics)',
#   4: '5,000 Awesome Facts (About Everything!) (National Geographic Kids)',
#   5: 'A Dance with Dragons (A Song of Ice and Fire)',
#   6: 'A Game of Thrones / A Clash of Kings / A Storm of Swords / A Feast of Crows / A Dance with Dragons',
#   7: 'A Gentleman in Moscow: A Novel',
#   8: 'A Higher Loyalty: Truth, Lies, and Leadership',
#   9: 'A Man Called Ove: A Novel',
#   10: 'A Man Called Ove: A Novel',
#   11: "A Patriot's History of the United States: From Columbus's Great Discovery to the War on Terror",
#   12: 'A Stolen Life: A Memoir',
#   13: 'A Wrinkle in Time (Time Quintet)',
#   14: 'Act Like a Lady, Think Like a Man: What Men Really Think About Love, Relationships, Intimacy, and Commitment',
# ...

# %%
house_interest = pd.DataFrame([['apartment', 0.35],['land', 0.18]], dtype=object)
house_interest.to_dict()
# Out:
# {0: {0: 'apartment', 1: 'land'}, 1: {0: 0.35, 1: 0.18}}

# %%
# Export Pandas DataFrames to csv and excel files --> easiear to share the result with others.
# Export to csv file
house_interest.to_csv(path_or_buf="data/house_interested.csv", index = False)

# %%
# Export to excel file
help(bookbestsellers.to_excel)
# Out:
# Help on method to_excel in module pandas.core.generic:
#
# to_excel(excel_writer, sheet_name: 'str' = 'Sheet1', na_rep: 'str' = '', float_format: 'str | None' = None, columns: 'Sequence[Hashable] | None' = None, header: 'Sequence[Hashable] | bool_t' = True, index: 'bool_t' = True, index_label: 'IndexLabel' = None, startrow: 'int' = 0, startcol: 'int' = 0, engine: 'str | None' = None, merge_cells: 'bool_t' = True, inf_rep: 'str' = 'inf', freeze_panes: 'tuple[int, int] | None' = None, storage_options: 'StorageOptions' = None) -> 'None' method of pandas.core.frame.DataFrame instance
#     Write object to an Excel sheet.
#
#     To write a single object to an Excel .xlsx file it is only necessary to
#     specify a target file name. To write to multiple sheets it is necessary to
#     create an `ExcelWriter` object with a target file name, and specify a sheet
#     in the file to write to.
#
#     Multiple sheets may be written to by specifying unique `sheet_name`.
# ...

# %%
bookbestsellers.to_excel(excel_writer="data/bootbestsellers.xlsx", index=False, engine='xlsxwriter')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[224], line 1
# ----> 1 bookbestsellers.to_excel(excel_writer="data/bootbestsellers.xlsx", index=False, engine='xlsxwriter')
#
# File c:\Python310\lib\site-packages\pandas\core\generic.py:2252, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options)
#    2239 from pandas.io.formats.excel import ExcelFormatter
#    2241 formatter = ExcelFormatter(
#    2242     df,
#    2243     na_rep=na_rep,
#    (...)
#    2250     inf_rep=inf_rep,
#    2251 )
# -> 2252 formatter.write(
#    2253     excel_writer,
#    2254     sheet_name=sheet_name,
#    2255     startrow=startrow,
#    2256     startcol=startcol,
#    2257     freeze_panes=freeze_panes,
#    2258     engine=engine,
# ...
